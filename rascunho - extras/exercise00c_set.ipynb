# %%
a = ("a", "b", "c")
a
# Out:
# ('a', 'b', 'c')

# %%
a = ("a", "b", "c", "a")
a
# Out:
# ('a', 'b', 'c', 'a')

# %%
a = set(("a", "b", "c", "a"))
a
# Out:
# {'a', 'b', 'c'}

# %%
a = set(["a", "b", "c", "a"])
a
# Out:
# {'a', 'b', 'c'}

# %%
b = set(["a", "b", "c", "d"])
b
# Out:
# {'a', 'b', 'c', 'd'}

# %%
a.difference(b)
# Out:
# set()

# %%
b.difference(a)
# Out:
# {'d'}

# %%
b.union(a)
# Out:
# {'a', 'b', 'c', 'd'}

# %%
b.intersection(a)
# Out:
# {'a', 'b', 'c'}
